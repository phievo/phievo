# %% [markdown]
# # Project Creator.
#
# Project creator is a jupyter notebook app that can be used to customize phievo's parameter and create a new project.
#
# *Run the next code cell to launch Project Creator*

# %%
from phievo.ConfigurationTools.application import App
aa = App()

aa.get_widget()
# Out:
# VBox(children=(HBox(children=(Text(value='', description='Project', placeholder='Enter the project name'), Label(value='A project cannot be an empty string or an existing directory.'))), Tab(children=(VBox(children=(HTML(value='<h2>Mutation parameters</h2><p>Set the values of the different mutation rates in the <code>dictionary_mutation</code> dictionary. For more information about <code>dictionary_mutation</code>, see the <a href="file:///home/adrien/Documents/Postdoc_PF/development_phievo/docs/build/html/parameters.html#mutation-parameters-dictionary-mutation">documentation</a>. </p>'), HBox(children=(HTML(value='<p>random_gene():</p>', layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.01, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>random_gene('TF'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.01, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>random_gene('Kinase'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.01, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>random_gene('Ligand'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.0, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>random_gene('Receptor'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.0, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>random_Interaction('TFHill'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.002, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>random_Interaction('PPI'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.002, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>random_Interaction('Phosphorylation'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.002, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>remove_Interaction('TFHill'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.005, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>remove_Interaction('PPI'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.005, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>remove_Interaction('CorePromoter'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.01, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>remove_Interaction('Phosphorylation'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.005, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>mutate_Node('Species'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.1, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>mutate_Node('TFHill'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.1, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(value="<p>mutate_Node('CorePromoter'):</p>", layout=Layout(height='30px', width='25%')), BoundedFloatText(value=0.1, description=' ', layout=Layout(height='10%', width='20%'), max=1000000.0, step=0.001))), HBox(children=(HTML(valu ...
# /home/adrien/Documents/Work/phievo/phievo/ConfigurationTools/default_cfiles
# Wrote hello/fitness.c
# Wrote hello/init_history.c
# Wrote hello/input.c
# Wrote hello/initialization.py
